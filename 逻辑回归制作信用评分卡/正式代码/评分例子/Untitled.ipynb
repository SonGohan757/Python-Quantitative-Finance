# %%
import pandas as pd
data = pd.read_csv("../ScoreData.csv")
data.head()
# Out:
#      base_score       [513.69958055]
# 0           age                Score
# 1  (-inf, 36.0]  -4.1489895082738375
# 2  (36.0, 54.0]  -2.1986464244371215
# 3  (54.0, 61.0]    1.972784640324442
# 4  (61.0, 74.0]    7.934720336058257

# %%
#先确定base_score
base_score = 513.7

# %%
df = pd.read_csv("../cs-test.csv")
df.head()
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1               NaN                              0.885519   43
# 1           2               NaN                              0.463295   57
# 2           3               NaN                              0.043275   59
# 3           4               NaN                              0.280308   38
# 4           5               NaN                              1.000000   27
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     0   0.177513         5700.0
# 1                                     0   0.527237         9141.0
# 2                                     0   0.687648         5083.0
# 3                                     1   0.925961         3200.0
# 4                                     0   0.019917         3865.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %% [markdown]
# 	SeriousDlqin2yrs	RevolvingUtilizationOfUnsecuredLines	age	NumberOfTime30-59DaysPastDueNotWorse	DebtRatio	MonthlyIncome	NumberOfOpenCreditLinesAndLoans	NumberOfTimes90DaysLate	NumberRealEstateLoansOrLines	NumberOfTime60-89DaysPastDueNotWorse	NumberOfDependents		得分
# 测试样本		0.88551908	43	0	0.177512717	5700	4	0	0	0	0
#
# 违约样本	1	0.025655677	38	0	0.475841386	3000	7	0	1	0	2
#
# 不违约样本	0	0.657792788	37	0	0.331326126	7306	4	0	1	0	2
# ![image.png](attachment:image.png)

# %%
#测试样本
print("测试样本：",513.7 -2.198646424-43.88822935+0.807701793-3.315386274-0.432076422+5.467155806+3.881818826-10.6601121+1.021526569+14.48663704)
print("违约样本：",513.7-2.198646424	+47.57442306	-8.570715929	-3.315386274	+1.029758821	+5.467155806	+3.881818826	+5.345219766	+1.021526569	-12.23968079
)
print("不违约样本：",513.7-2.198646424-23.20813408-8.570715929+3.358845807+1.029758821-24.01190636+3.881818826+5.345219766-11.37043363+14.48663704)
# Out:
# 测试样本： 478.870389464
# 违约样本： 551.695473431
# 不违约样本： 472.44244383700004
